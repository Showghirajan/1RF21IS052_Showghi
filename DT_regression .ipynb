# %%
import pandas as pd

# %%
import numpy as np

# %%
walmart_df=pd.read_csv('Walmart_sales.csv')

# %%
walmart_df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
len(np.unique(walmart_df['Store']))
# Out:
# 45

# %%
#walmart_df.corr(numeric_only=True)
numeric_df = walmart_df.select_dtypes(include='number')
numeric_df.corr()
# Out:
#                      Store  Weekly_Sales  Holiday_Flag  Temperature  \
# Store         1.000000e+00     -0.335332 -4.386841e-16    -0.022659
# Weekly_Sales -3.353320e-01      1.000000  3.689097e-02    -0.063810
# Holiday_Flag -4.386841e-16      0.036891  1.000000e+00    -0.155091
# Temperature  -2.265908e-02     -0.063810 -1.550913e-01     1.000000
# Fuel_Price    6.002295e-02      0.009464 -7.834652e-02     0.144982
# CPI          -2.094919e-01     -0.072634 -2.162091e-03     0.176888
# Unemployment  2.235313e-01     -0.106176  1.096028e-02     0.101158
#
#               Fuel_Price       CPI  Unemployment
# Store           0.060023 -0.209492      0.223531
# Weekly_Sales    0.009464 -0.072634     -0.106176
# Holiday_Flag   -0.078347 -0.002162      0.010960
# Temperature     0.144982  0.176888      0.101158
# Fuel_Price      1.000000 -0.170642     -0.034684
# CPI            -0.170642  1.000000     -0.302020
# Unemployment   -0.034684 -0.302020      1.000000

# %%
walmart_df['Date']
# Out:
# 0       05-02-2010
# 1       12-02-2010
# 2       19-02-2010
# 3       26-02-2010
# 4       05-03-2010
#            ...
# 6430    28-09-2012
# 6431    05-10-2012
# 6432    12-10-2012
# 6433    19-10-2012
# 6434    26-10-2012
# Name: Date, Length: 6435, dtype: object

# %%
walmart_df['Date'] = pd.to_datetime(walmart_df['Date'], format='%d-%m-%Y')

walmart_df['Day']= walmart_df['Date'].dt.day


walmart_df['Month']= walmart_df['Date'].dt.month
walmart_df['Year']= walmart_df['Date'].dt.year

# %%
walmart_df['Year']
# Out:
# 0       2010
# 1       2010
# 2       2010
# 3       2010
# 4       2010
#         ...
# 6430    2012
# 6431    2012
# 6432    2012
# 6433    2012
# 6434    2012
# Name: Year, Length: 6435, dtype: int64

# %%
walmart_numeric=walmart_df.select_dtypes(include='number')

# %%
walmart_numeric
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Day  Month  Year
# 0            8.106    5      2  2010
# 1            8.106   12      2  2010
# 2            8.106   19      2  2010
# 3            8.106   26      2  2010
# 4            8.106    5      3  2010
# ...            ...  ...    ...   ...
# 6430         8.684   28      9  2012
# 6431         8.667    5     10  2012
# 6432         8.667   12     10  2012
# 6433         8.667   19     10  2012
# 6434         8.667   26     10  2012
#
# [6435 rows x 10 columns]

# %%
walmart_numeric.corr()
# Out:
#                      Store  Weekly_Sales  Holiday_Flag  Temperature  \
# Store         1.000000e+00     -0.335332 -4.386841e-16    -0.022659
# Weekly_Sales -3.353320e-01      1.000000  3.689097e-02    -0.063810
# Holiday_Flag -4.386841e-16      0.036891  1.000000e+00    -0.155091
# Temperature  -2.265908e-02     -0.063810 -1.550913e-01     1.000000
# Fuel_Price    6.002295e-02      0.009464 -7.834652e-02     0.144982
# CPI          -2.094919e-01     -0.072634 -2.162091e-03     0.176888
# Unemployment  2.235313e-01     -0.106176  1.096028e-02     0.101158
# Day           1.478526e-15     -0.017409  4.452608e-02     0.026973
# Month         2.910676e-15      0.076143  1.229958e-01     0.235862
# Year          3.474318e-12     -0.018378 -5.678257e-02     0.064269
#
#               Fuel_Price       CPI  Unemployment           Day         Month  \
# Store           0.060023 -0.209492      0.223531  1.478526e-15  2.910676e-15
# Weekly_Sales    0.009464 -0.072634     -0.106176 -1.740946e-02  7.614332e-02
# Holiday_Flag   -0.078347 -0.002162      0.010960  4.452608e-02  1.229958e-01
# Temperature     0.144982  0.176888      0.101158  2.697332e-02  2.358618e-01
# Fuel_Price      1.000000 -0.170642     -0.034684  2.807253e-02 -4.215590e-02
# CPI            -0.170642  1.000000     -0.302020  2.684300e-03  4.979672e-03
# Unemployment   -0.034684 -0.302020      1.000000 -4.233293e-03 -1.274559e-02
# Day             0.028073  0.002684     -0.004233  1.000000e+00  1.519184e-02
# Month          -0.042156  0.004980     -0.012746  1.519184e-02  1.000000e+00
# Year            0.779470  0.074796     -0.241813  6.405867e-03 -1.944645e-01
#
#                       Year
# Store         3.474318e-12
# Weekly_Sales -1.837754e-02
# Holiday_Flag -5.678257e-02
# Temperature   6.426923e-02
# Fuel_Price    7.794703e-01
# CPI           7.479573e-02
# Unemployment -2.418135e-01
# Day           6.405867e-03
# Month        -1.944645e-01
# Year          1.000000e+00

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\lochan\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\lochan\anaconda3\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\lochan\anaconda3\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.23 in c:\users\lochan\anaconda3\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\lochan\anaconda3\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\lochan\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lochan\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lochan\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lochan\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lochan\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\lochan\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lochan\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lochan\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\lochan\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lochan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lochan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lochan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lochan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lochan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lochan\anaconda3\lib\site-packages)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
numeric_df = walmart_df.select_dtypes(include='number')
plt.figure(figsize=(12, 10))
sns.heatmap(numeric_df.corr(), cmap='Blues', annot=True);

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(walmart_df['Weekly_Sales'], bins=20, kde=True)
plt.title('Distribution of Weekly Sales')
# Out:
# Text(0.5, 1.0, 'Distribution of Weekly\xa0Sales')

# %%
plt.figure(figsize=(20, 20))
sns.pairplot(data=walmart_df, x_vars=['Holiday_Flag', 'Temperature',
                                      'Fuel_Price', 'CPI', 'Unemployment',
                                      'Day', 'Month', 'Year'],
             y_vars=['Weekly_Sales'], kind='scatter', height=5)
plt.show()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
num_cols = 3
num_rows = (len(walmart_df.columns) - 1) // num_cols + 1

fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 20))

axes = axes.flatten()

for i, col in enumerate(walmart_df.columns):

    sns.histplot(walmart_df[col], kde=True, ax=axes[i])
    axes[i].set_title(f'Histogram with KDE for {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')
plt.show()

# %%
store_sales = walmart_df.groupby('Store')['Weekly_Sales'].sum().sort_values(ascending=False)
store_sales
# Out:
# Store
# 20    3.013978e+08
# 4     2.995440e+08
# 14    2.889999e+08
# 13    2.865177e+08
# 2     2.753824e+08
# 10    2.716177e+08
# 27    2.538559e+08
# 6     2.237561e+08
# 1     2.224028e+08
# 39    2.074455e+08
# 19    2.066349e+08
# 31    1.996139e+08
# 23    1.987506e+08
# 24    1.940160e+08
# 11    1.939628e+08
# 28    1.892637e+08
# 41    1.813419e+08
# 32    1.668192e+08
# 18    1.551147e+08
# 22    1.470756e+08
# 12    1.442872e+08
# 26    1.434164e+08
# 34    1.382498e+08
# 40    1.378703e+08
# 35    1.315207e+08
# 8     1.299512e+08
# 17    1.277821e+08
# 45    1.123953e+08
# 21    1.081179e+08
# 25    1.010612e+08
# 43    9.056544e+07
# 15    8.913368e+07
# 7     8.159828e+07
# 42    7.956575e+07
# 9     7.778922e+07
# 29    7.714155e+07
# 16    7.425243e+07
# 37    7.420274e+07
# 30    6.271689e+07
# 3     5.758674e+07
# 38    5.515963e+07
# 36    5.341221e+07
# 5     4.547569e+07
# 44    4.329309e+07
# 33    3.716022e+07
# Name: Weekly_Sales, dtype: float64

# %%
plt.figure(figsize=(15, 10))
store_sales.plot(kind='bar')
plt.title('Total Weekly Sales by Store')
plt.xlabel('Store')
plt.ylabel('Total Weekly Sales')
plt.xticks(rotation=90)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = walmart_df.drop(['Weekly_Sales', 'Date'], axis=1)
y = walmart_df['Weekly_Sales']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, 
                                                   random_state=101)

# %%
y_train
# Out:
# 1214     550076.32
# 4729     923344.54
# 1583     957997.52
# 3060     944587.23
# 2481     891148.55
#            ...
# 599      286477.35
# 5695     967729.35
# 1361    1699708.38
# 1547    1370251.22
# 4959    1115255.65
# Name: Weekly_Sales, Length: 5148, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor

# Create the model
model = DecisionTreeRegressor()

# Train the model (assuming X_train and y_train are your training features and labels)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# %%
model
# Out:
# DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

rmse1 =np.sqrt(mean_squared_error(y_test, y_pred))
rmse1
# Out:
# 134898.05772734058

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Visualize the decision tree
plt.figure(figsize=(20, 10))
plot_tree(model, filled=True, feature_names=X.columns)
plt.show()
